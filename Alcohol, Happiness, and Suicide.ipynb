# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
alcohol_csv = "Data/HappinessAlcoholConsumption.csv"
alcohol_df = pd.read_csv(alcohol_csv)
alcohol_df.head()
# Out:
#        Country          Region Hemisphere  HappinessScore  HDI  GDP_PerCapita  \
# 0      Denmark  Western Europe      north           7.526  928         53.579
# 1  Switzerland  Western Europe      north           7.509  943         79.866
# 2      Iceland  Western Europe      north           7.501  933         60.530
# 3       Norway  Western Europe      north           7.498  951         70.890
# 4      Finland  Western Europe      north           7.413  918         43.433
#
#    Beer_PerCapita  Spirit_PerCapita  Wine_PerCapita
# 0             224                81             278
# 1             185               100             280
# 2             233                61              78
# 3             169                71             129
# 4             263               133              97

# %%
alcohol_sort = alcohol_df.sort_values("Country", ascending=True)
alcohol_sort.head()
# Out:
#        Country                       Region Hemisphere  HappinessScore  HDI  \
# 88     Albania   Central and Eastern Europe      north           4.655  782
# 112     Angola           Sub-Saharan Africa      south           3.866  577
# 24   Argentina  Latin America and Caribbean      south           6.650  822
# 94     Armenia   Central and Eastern Europe      north           4.360  749
# 8    Australia    Australia and New Zealand      south           7.313  938
#
#      GDP_PerCapita  Beer_PerCapita  Spirit_PerCapita  Wine_PerCapita
# 88           4.132              89               132              54
# 112          3.309             217                57              45
# 24          12.654             193                25             221
# 94           3.606              21               179              11
# 8           49.897             261                72             212

# %%
suicide_csv = "Data/data.csv"
suicide_df = pd.read_csv(suicide_csv)
suicide_df.head()
# Out:
#     Unnamed: 0  Unnamed: 1  \
# 0      Country         Sex
# 1  Afghanistan  Both sexes
# 2  Afghanistan        Male
# 3  Afghanistan      Female
# 4      Albania  Both sexes
#
#    Age-standardized suicide rates (per 100 000 population)
# 0                                             2016.0
# 1                                                6.4
# 2                                               10.6
# 3                                                2.1
# 4                                                5.6

# %%
suicide_rn = suicide_df.rename(columns={"Unnamed: 0":"Country","Unnamed: 1":"Sex","Age-standardized suicide rates (per 100 000 population)":"Suicide Rates"})
suicide_rn.head()
# Out:
#        Country         Sex  Suicide Rates
# 0      Country         Sex         2016.0
# 1  Afghanistan  Both sexes            6.4
# 2  Afghanistan        Male           10.6
# 3  Afghanistan      Female            2.1
# 4      Albania  Both sexes            5.6

# %%
suicide_final = suicide_rn.drop(suicide_rn.index[[0]])
suicide_final.head()
# Out:
#        Country         Sex  Suicide Rates
# 1  Afghanistan  Both sexes            6.4
# 2  Afghanistan        Male           10.6
# 3  Afghanistan      Female            2.1
# 4      Albania  Both sexes            5.6
# 5      Albania        Male            7.0
